# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
message = client.messages.create(
    model=model,
    max_tokens=10000,
    messages=[
        {
            "role": "user",
            "content": "Give me a *really* short history of Russia."
        }
    ]
)

# %%
type(message)
# Out:
# anthropic.types.message.Message

# %%
message.content[0].text
# Out:
# '# A Really Short History of Russia\n\n**Early days:** Viking-influenced Slavs built a state around Kiev (Kievan Rus, ~800s). Mongols smashed it in the 1200s.\n\n**Rising Moscow:** Moscow gradually threw off Mongol rule. Ivan the Terrible became the first Tsar (1547). Lots of expansion, lots of brutality.\n\n**Romanovs:** Peter the Great modernized and westernized (forcibly). Catherine the Great expanded the empire. Russia became a major European power.\n\n**19th century:** Defeated Napoleon. Then fell behind industrially, lost the Crimean War, and grew politically restless.\n\n**Revolution:** WWI broke the system. Tsar Nicholas II abdicated (1917). Lenin and the Bolsheviks took over. Civil war. Soviet Union formed (1922).\n\n**Soviet era:** Stalin industrialized brutally, won WWII at enormous cost (~27 million dead), then launched the Cold War against the West.\n\n**Collapse:** Gorbachev tried to reform things. The USSR fell apart in **1991**.\n\n**Modern Russia:** Chaotic 1990s under Yeltsin. Then Vladimir Putin took power (2000) and never really let go — centralizing authority and reasserting Russian power, most dramatically by invading Ukraine.'

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
messages = []

while True:
    try:
        user_input = input("> ")
        print(">", user_input)
    except (KeyboardInterrupt, EOFError):
        print("\nGoodbye!")
        break

    if user_input.strip().lower() in ("quit", "exit", "q") or not user_input.strip():
        print("Goodbye!")
        break

    add_user_message(messages, user_input)

    response = chat(messages)
    print("---\n", response)

    add_assistant_message(messages, response)
    print("---\n")
# Out:
# Goodbye!
